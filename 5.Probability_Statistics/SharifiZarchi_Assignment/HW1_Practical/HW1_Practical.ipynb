# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="IranNastaliq" size=30>
# 				<p></p>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# 			<font color=#FF7500>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# 			<font color=blue>
# آمار و احتمال مهندسی
#             </font>
# 			<br />
# 			<br />
# پاییز ۱۳۹۸
# 		</div>
# 		<hr/>
# 		<div align=center>
# 		    <font color=red size=6>
# 			    <br />
# تمرین عملی بخش اول
#             	<br/>
# 			</font>
# طراح: سروش فرقدانی - علیرضا اکبری
# 			<br/><br/>
# موعد تحویل: ...
#                 <br/>
#                 همفکری در تمامی تمرین‌های درس توصیه می‌شود. در عین حال از شما خواسته می‌شود تا تمام پیاده‌سازی را به تنهایی و بدون مشاهده کد دیگران انجام دهید.
#                 <br/><br/>
#                 <font color=red>
#                 لطفا در فایل ارسالی تمام بلوک‌های کد اجرا شده و شامل نمودار‌ها و خروجی‌های لازم باشند.
#      </font>
#                 <br/>
#         </style>
# 	</font>
# </div>

# %% [raw]
# نام و نام خانوادگی

# %% [raw]
# شماره دانشجویی

# %% [raw]
# نام افرادی که با آنها مشورت کرده اید

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             سوال اول
#         </font>
#         <hr>
#         در این سوال قصد داریم مساله‌ی حیرت انگیر 'تولد مشترک' را به طور عملی بررسی کنیم!!
#         <br>
#                 فرض کنید k نفر در یک جشن حضور بهم می‌رسانند. اگر دو نفر در میان این k  نفر در یک روز به دنیا آمده باشند, می‌توانند به طور مشترک تولد بگیرند و بدین ترتیب هزینه‌ها را بین دو نفر تقسیم کنند.(( توجه کنید که سال تولد مهم نیست . یعنی مثلا اگر یک نفر در ۶ آبان ۱۳۳۵ به دنیا آمده باشد , می‌تواند با یک فرد که در ۶ آبان ۱۳۶۱ به دنیا آمده به طور مشترک تولد بگیرد))
#         <ul>
#             <li>
#                 عدد k حداقل باید چقدر باشد تا احتمال این که پدیده‌ی 'تولد مشترک' رخ دهد , بیشتر از 0.5 باشد؟
#             <br>
#                 راهنمایی: شروع به حدس زدن k بکنید . برای هر حدس , ۱۰۰ بار جشنی با k  نفر را شبیه سازی کنید و در نهایت با توجه به شبیه‌سازی خود احتمال وجود ' تولد مشترک ' را برای آن k بدست آورید.
#             </li>
#         </ul>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#         </font>
#         پاسخ:
# 	</font>
# </div>

# %%
k <- 23
check_rands <- function(k){
    birthdays <- sample(1:365, k, replace= TRUE)
    return (length(unique(birthdays)) < length(birthdays))
}

out <- replicate(100, check_rands(k))
print(length(out[out==FALSE]) / length(out))
# Out:
# [1] 0.55

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             سوال دوم
#         </font>
#         <hr/>
#         داده spanish_league که در اختیار شما قرارگرفته است اطلاعاتی مانند زمان بازی‌های برگذار شده , نتایج آن‌ها و تیم‌های برگذارکننده‌ی بازی‌ها را در اختیار شما قرار میدهد. هر سطر از این داده، شامل اطلاعات یک بازی است. با استفاده از این داده موارد خواسته شده را بیابید:
#         <br/>
#         <ul>
#             <li>
#                 بازی‌های با تعداد گل‌های زده شده بیشتر از ۷ و همچنین بازی‌های با تعداد گل‌های زده شده کمتر از ۲ را در یک دیتافریم جدید ذخیره کنید.
#             </li>
#         </ul>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#         </font>
#         پاسخ:
# 	</font>
# </div>

# %%
league_df <- read.csv("spanish_league.csv")
league_df$totalGoals <- league_df$localGoals + league_df$visitorGoals
new_df <- league_df[league_df$totalGoals > 7 | league_df$totalGoals < 2,]
head(new_df)
# Out:
#    id season  division round localTeam visitorTeam   localGoals visitorGoals
# 6   6 1970-71 1        1     Espanol   Sevilla       0          1
# 7   7 1970-71 1        1     Sabadell  Real Sociedad 0          0
# 8   8 1970-71 1        1     Zaragoza  CD Malaga     0          0
# 13 13 1970-71 1        2     Granada   Espanol       1          0
# 19 19 1970-71 1        3     Valencia  Sevilla       0          1
# 22 22 1970-71 1        3     Espanol   Real Sociedad 0          0
#    date       timestamp totalGoals
# 6  13/09/1970 22024800  1
# 7  13/09/1970 22024800  0
# 8  13/09/1970 22024800  0
# 13 20/09/1970 22629600  1
# 19 26/09/1970 23148000  1
# 22 27/09/1970 23234400  0

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <ul>
#             <li>
#                 اگر یک بازی را بطور تصادفی از دیتافریم بالا انتخاب کنیم , احتمال این که مربوط به فصل 83-1982 باشد , چقدر است؟
#             </li>
#         </ul>
# 	</font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#         </font>
#         پاسخ:
# 	</font>
# </div>

# %%
nrow(new_df[new_df$season == "1982-83",]) / nrow(new_df)
# Out:
# [1] 0.01736141

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <ul>
#             <li>
#                 بازی‌ها را برحسب تعداد گل‌های زده شده توسط میهمان مرتب کنید و ۳ بازی اول را چاپ کنید.
#             </li>
#         </ul>
# 	</font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#         </font>
#         پاسخ:
# 	</font>
# </div>

# %%
sorted <- league_df[order(league_df$visitorGoal), ]
head(sorted, 3)
# Out:
#   id season  division round localTeam     visitorTeam       localGoals
# 3 3  1970-71 1        1     Real Madrid   Valencia          2
# 4 4  1970-71 1        1     Celta de Vigo Sporting de Gijon 2
# 7 7  1970-71 1        1     Sabadell      Real Sociedad     0
#   visitorGoals date       timestamp totalGoals
# 3 0            12/09/1970 21938400  2
# 4 0            13/09/1970 22024800  2
# 7 0            13/09/1970 22024800  0

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             سوال سوم
#         </font>
#         <hr>
#         داده spanish_league را مجدد بخوانید و با استفاده از این داده موارد خواسته شده را بیابید:
#         <ul>
#             <li>
#                 نمودار مستطیلی تعداد گل‌های زده شده را رسم کنید.
#             </li>
#         </ul>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#         </font>
#         پاسخ:
# 	</font>
# </div>

# %%
hist(league_df$totalGoals)
# Out:
# Plot with title “Histogram of league_df$totalGoals”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <ul>
#             <li>
#                 نموداری بکشید که ستون عمودی آن نشان‌دهندەی گل‌های زده شده توسط میزبان و ستون افقی
# نشان‌دهندەی گل‌های زده شده توسط میهمان باشد. سپس بازی‌ها را در این نمودار رسم کنید به نحوی که  بازی‌های برگزار شده در فصل 98-1997 قرمز باشند و بقیه آبی.
#             </li>
#         </ul>
# 	</font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#         </font>
#         پاسخ:
# 	</font>
# </div>

# %%
library(ggplot2)
league_df$season97 <- c(league_df$season == '1997-98')
sorted <- league_df[order(league_df$season97), ]
ggplot(data = sorted, aes(visitorGoals, localGoals, color= season97)) +
    geom_point()
# Out:
#       id    season  division round localTeam          visitorTeam
# 1      1    1970-71 1        1     Atletico de Bilbao Barcelona
# 2      2    1970-71 1        1     Las Palmas         Atletico de Madrid
# 3      3    1970-71 1        1     Real Madrid        Valencia
# 4      4    1970-71 1        1     Celta de Vigo      Sporting de Gijon
# 5      5    1970-71 1        1     Elche              Granada
# 6      6    1970-71 1        1     Espanol            Sevilla
# 7      7    1970-71 1        1     Sabadell           Real Sociedad
# 8      8    1970-71 1        1     Zaragoza           CD Malaga
# 9      9    1970-71 1        2     Valencia           Las Palmas
# 10    10    1970-71 1        2     Atletico de Madrid Atletico de Bilbao
# 11    11    1970-71 1        2     Barcelona          Zaragoza
# 12    12    1970-71 1        2     Sporting de Gijon  Sabadell
# 13    13    1970-71 1        2     Granada            Espanol
# 14    14    1970-71 1        2     CD Malaga          Celta de Vigo
# 15    15    1970-71 1        2     Real Sociedad      Elche
# 16    16    1970-71 1        2     Sevilla            Real Madrid
# 17    17    1970-71 1        3     Las Palmas         Atletico de Bilbao
# 18    18    1970-71 1        3     Real Madrid        Granada
# 19    19    1970-71 1        3     Valencia           Sevilla
# 20    20    1970-71 1        3     Celta de Vigo      Barcelona
# 21    21    1970-71 1        3     Elche              Sporting de Gijon
# 22    22    1970-71 1        3     Espanol            Real Sociedad
# 23    23    1970-71 1        3     Sabadell           CD Malaga
# 24    24    1970-71 1        3     Zaragoza           Atletico de Madrid
# 25    25    1970-71 1        4     Atletico de Bilbao Zaragoza
# 26    26    1970-71 1        4     Atletico de Madrid Celta de Vigo
# 27    27    1970-71 1        4     Barcelona          Sabadell
# 28    28    1970-71 1        4     Sporting de Gijon  Espanol
# 29    29    1970-71 1        4     Granada            Valencia
# 30    30    1970-71 1        4     Las Palmas         Sevilla
# ⋮     ⋮     ⋮       ⋮        ⋮     ⋮                  ⋮
# 20278 20278 1997-98 2        40    Osasuna            Numancia
# 20279 20279 1997-98 2        40    Alaves             Rayo Vallecano
# 20280 20280 1997-98 2        40    Leganes            Villarreal
# 20281 20281 1997-98 2        40    Logrones           Eibar
# 20282 20282 1997-98 2        40    Extremadura        Lleida
# 20283 20283 1997-98 2        40    Levante            Hercules
# 20284 20284 1997-98 2        40    Atletico Madrileno Toledo
# 20285 20285 1997-98 2        40    Sevilla            Albacete
# 20286 20286 1997-98 2        41    Ourense            Extremadura
# 20287 20287 1997-98 2        41    Toledo             Leganes
# 20288 20288 1997-98 2        41    Lleida             Badajoz
# 20289 20289 1997-98 2        41    Villarreal         Alaves
# 20290 20290 1997-98 2        41    Hercules           Osasuna
# 20291 20291 1997-98 2        41    Rayo Vallecano     Levante
# 20292 20292 1997-98 2        41    Jaen               Elche
# 20293 20293 1997-98 2        41    Eibar              Sevilla
# 20294 20294 1997-98 2        41    Las Palmas         Logrones
# 20295 20295 1997-98 2        41    Xerez              Numancia
# 20296 20296 1997-98 2        41    Albacete           Atletico Madrileno
# 20297 20297 1997-98 2        42    Levante            Villarreal
# 20298 20298 1997-98 2        42    Sevilla            Las Palmas
# 20299 20299 1997-98 2        42    Osasuna            Rayo Vallecano
# 20300 20300 1997-98 2        42    Alaves             Toledo
# 20301 20301 1997-98 2        42    Badajoz            Ourense
# 20302 20302 1997-98 2        42    Leganes            Albacete
# 20303 20303 1997-98 2        42    Logrones           Lleida
# 20304 20304 1997-98 2        42    Numancia           Hercules
# 20305 20305 1997-98 2        42    Extremadura        Jaen
# 20306 20306 1997-98 2        42    Elche              Xerez
# 20307 20307 1997-98 2        42    Atletico Madrileno Eibar
#       localGoals visitorGoals date       timestamp totalGoals season97
# 1     1          1            12/09/1970 21938400  2          FALSE
# 2     1          1            12/09/1970 21938400  2          FALSE
# 3     2          0            12/09/1970 21938400  2          FALSE
# 4     2          0            13/09/1970 22024800  2          FALSE
# 5     1          1            13/09/1970 22024800  2          FALSE
# 6     0          1            13/09/1970 22024800  1          FALSE
# 7     0          0            13/09/1970 22024800  0          FALSE
# 8     0          0            13/09/1970 22024800  0          FALSE
# 9     5          1            19/09/1970 22543200  6          FALSE
# 10    2          0            20/09/1970 22629600  2          FALSE
# 11    5          2            20/09/1970 22629600  7          FALSE
# 12    3          2            20/09/1970 22629600  5          FALSE
# 13    1          0            20/09/1970 22629600  1          FALSE
# 14    2          1            20/09/1970 22629600  3          FALSE
# 15    2          0            20/09/1970 22629600  2          FALSE
# 16    3          1            20/09/1970 22629600  4          FALSE
# 17    1          1            26/09/1970 23148000  2          FALSE
# 18    3          2            26/09/1970 23148000  5          FALSE
# 19    0          1            26/09/1970 23148000  1          FALSE
# 20    1          1            27/09/1970 23234400  2          FALSE
# 21    5          0            27/09/1970 23234400  5          FALSE
# 22    0          0            27/09/1970 23234400  0          FALSE
# 23    5          2            27/09/1970 23234400  7          FALSE
# 24    0          1            27/09/1970 23234400  1          FALSE
# 25    3          0            04/10/1970 23839200  3          FALSE
# 26    3          1            04/10/1970 23839200  4          FALSE
# 27    4          1            04/10/1970 23839200  5          FALSE
# 28    0          1            04/10/1970 23839200  1          FALSE
# 29    2          2            04/10/1970 23839200  4          FALSE
# 30    0          0            04/10/1970 23839200  0          FALSE
# ⋮     ⋮          ⋮            ⋮          ⋮         ⋮          ⋮
# 20278 0          1            03/05/1998 894146400 1          TRUE
# 20279 3          0            03/05/1998 894146400 3          TRUE
# 20280 0          2            03/05/1998 894146400 2          TRUE
# 20281 1          1            03/05/1998 894146400 2          TRUE
# 20282 3          0            03/05/1998 894146400 3          TRUE
# 20283 0          0            03/05/1998 894146400 0          TRUE
# 20284 2          1            03/05/1998 894146400 3          TRUE
# 20285 2          0            06/05/1998 894405600 2          TRUE
# 20286 0          1            09/05/1998 894664800 1          TRUE
# 20287 3          2            09/05/1998 894664800 5          TRUE
# 20288 2          0            09/05/1998 894664800 2          TRUE
# 20289 2          1            09/05/1998 894664800 3          TRUE
# 20290 0          0            10/05/1998 894751200 0          TRUE
# 20291 3          0            10/05/1998 894751200 3          TRUE
# 20292 2          1            10/05/1998 894751200 3          TRUE
# 20293 1          1            10/05/1998 894751200 2          TRUE
# 20294 0          4            10/05/1998 894751200 4          TRUE
# 20295 2          2            10/05/1998 894751200 4          TRUE
# 20296 1          1            10/05/1998 894751200 2          TRUE
# 20297 1          2            15/05/1998 895183200 3          TRUE
# 20298 1          1            15/05/1998 895183200 2          TRUE
# 20299 1          3            16/05/1998 895269600 4          TRUE
# 20300 3          0            16/05/1998 895269600 3          TRUE
# 20301 2          0            16/05/1998 895269600 2          TRUE
# 20302 0          2            16/05/1998 895269600 2          TRUE
# 20303 0          1            16/05/1998 895269600 1          TRUE
# 20304 0          0            16/05/1998 895269600 0          TRUE
# 20305 2          2            16/05/1998 895269600 4          TRUE
# 20306 1          0            16/05/1998 895269600 1          TRUE
# 20307 2          0            16/05/1998 895269600 2          TRUE
#       palyed_in_97
# 1     FALSE
# 2     FALSE
# 3     FALSE
# 4     FALSE
# 5     FALSE
# 6     FALSE
# 7     FALSE
# 8     FALSE
# 9     FALSE
# 10    FALSE
# 11    FALSE
# 12    FALSE
# 13    FALSE
# 14    FALSE
# 15    FALSE
# 16    FALSE
# 17    FALSE
# 18    FALSE
# 19    FALSE
# 20    FALSE
# 21    FALSE
# 22    FALSE
# 23    FALSE
# 24    FALSE
# 25    FALSE
# 26    FALSE
# 27    FALSE
# 28    FALSE
# 29    FALSE
# 30    FALSE
# ⋮     ⋮
# 20278 TRUE
# 20279 TRUE
# 20280 TRUE
# 20281 TRUE
# 20282 TRUE
# 20283 TRUE
# 20284 TRUE
# 20285 TRUE
# 20286 TRUE
# 20287 TRUE
# 20288 TRUE
# 20289 TRUE
# 20290 TRUE
# 20291 TRUE
# 20292 TRUE
# 20293 TRUE
# 20294 TRUE
# 20295 TRUE
# 20296 TRUE
# 20297 TRUE
# 20298 TRUE
# 20299 TRUE
# 20300 TRUE
# 20301 TRUE
# 20302 TRUE
# 20303 TRUE
# 20304 TRUE
# 20305 TRUE
# 20306 TRUE
# 20307 TRUE
# plot without title
